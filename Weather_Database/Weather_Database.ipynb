# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
  # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")    



record_count = 1
time.sleep(60)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | westport
# Processing Record 3 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | shimoda
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | pisco
# Processing Record 8 of Set 1 | gejiu
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | kavieng
# Processing Record 13 of Set 1 | hambantota
# Processing Record 14 of Set 1 | tuatapere
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | mana
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | half moon bay
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | goderich
# Processing Record 26 of Set 1 | wad madani
# Processing Record 27 of Set 1 | vila franca do campo
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | dalbandin
# Processing Record 32 of Set 1 | ondjiva
# Processing Record 33 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 1 | tiznit
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | pacific grove
# Processing Record 40 of Set 1 | santa maria
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | awbari
# Processing Record 44 of Set 1 | havelock
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | mount abu
# Processing Record 47 of Set 1 | honiara
# Processing Record 48 of Set 1 | pitimbu
# Processing Record 49 of Set 1 | mehamn
# Processing Record 50 of Set 1 | grand gaube
# Processing Record 51 of Set 2 | namibe
# Processing Record 52 of Set 2 | barrow
# Processing Record 53 of Set 2 | severo-kurilsk
# Processing Record 54 of Set 2 | salinopolis
# Processing Record 55 of Set 2 | faya
# Processing Record 56 of Set 2 | vostok
# Processing Record 57 of Set 2 | cape town
# Processing Record 58 of Set 2 | chokurdakh
# Processing Record 59 of Set 2 | trincomalee
# Processing Record 60 of Set 2 | oktyabrskiy
# Processing Record 61 of Set 2 | georgetown
# Processing Record 62 of Set 2 | pushkino
# Processing Record 63 of Set 2 | general pico
# Processing Record 64 of Set 2 | ayios kirikos
# City not found. Skipping...
# Processing Record 65 of Set 2 | saint-joseph
# Processing Record 66 of Set 2 | bluff
# Processing Record 67 of Set 2 | svetlogorsk
# Processing Record 68 of Set 2 | asau
# Processing Record 69 of Set 2 | port alfred
# Processing Record 70 of Set 2 | lakes entrance
# Processing Record 71 of Set 2 | tasiilaq
# Processing Record 72 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 73 of Set 2 | touros
# Processing Record 74 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 75 of Set 2 | busselton
# Processing Record 76 of Set 2 | leshukonskoye
# Processing Record 77 of Set 2 | atuona
# Processing Record 78 of Set 2 | victoria
# Processing Record 79 of Set 2 | avera
# Processing Record 80 of Set 2 | olafsvik
# Processing Record 81 of Set 2 | kapaa
# Processing Record 82 of Set 2 | trelew
# Processing Record 83 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 84 of Set 2 | guanica
# Processing Record 85 of Set 2 | mokhsogollokh
# Processing Record 86 of Set 2 | yelizovo
# Processing Record 87 of Set 2 | orebro
# Processing Record 88 of Set 2 | taraz
# Processing Record 89 of Set 2 | fare
# Processing Record 90 of Set 2 | thompson
# Processing Record 91 of Set 2 | udachnyy
# Processing Record 92 of Set 2 | upernavik
# Processing Record 93 of Set 2 | baker city
# Processing Record 94 of Set 2 | hovd
# Processing Record 95 of Set 2 | lagoa
# Processing Record 96 of Set 2 | cidreira
# Processing Record 97 of Set 2 | longyearbyen
# Processing Record 98 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 99 of Set 2 | huarmey
# Processing Record 100 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 101 of Set 3 | luderitz
# Processing Record 102 of Set 3 | nikolskoye
# Processing Record 103 of Set 3 | fairbanks
# Processing Record 104 of Set 3 | ponta do sol
# Processing Record 105 of Set 3 | papa
# Processing Record 106 of Set 3 | souillac
# Processing Record 107 of Set 3 | saldanha
# Processing Record 108 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 109 of Set 3 | hasaki
# Processing Record 110 of Set 3 | yuncheng
# Processing Record 111 of Set 3 | bilibino
# Processing Record 112 of Set 3 | mazagao
# Processing Record 113 of Set 3 | koslan
# Processing Record 114 of Set 3 | komsomolskiy
# Processing Record 115 of Set 3 | airai
# Processing Record 116 of Set 3 | nemuro
# Processing Record 117 of Set 3 | yerbogachen
# Processing Record 118 of Set 3 | road town
# Processing Record 119 of Set 3 | san patricio
# Processing Record 120 of Set 3 | khipro
# Processing Record 121 of Set 3 | hithadhoo
# Processing Record 122 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 123 of Set 3 | chicaman
# Processing Record 124 of Set 3 | alvdal
# Processing Record 125 of Set 3 | gari
# Processing Record 126 of Set 3 | elliot lake
# Processing Record 127 of Set 3 | katobu
# Processing Record 128 of Set 3 | kaitangata
# Processing Record 129 of Set 3 | provideniya
# Processing Record 130 of Set 3 | tuktoyaktuk
# Processing Record 131 of Set 3 | chake chake
# Processing Record 132 of Set 3 | pevek
# Processing Record 133 of Set 3 | jasidih
# Processing Record 134 of Set 3 | east london
# Processing Record 135 of Set 3 | malpe
# Processing Record 136 of Set 3 | kodiak
# Processing Record 137 of Set 3 | zhezkazgan
# Processing Record 138 of Set 3 | tura
# Processing Record 139 of Set 3 | andenes
# Processing Record 140 of Set 3 | tauranga
# Processing Record 141 of Set 3 | mahebourg
# Processing Record 142 of Set 3 | port elizabeth
# Processing Record 143 of Set 3 | sabang
# Processing Record 144 of Set 3 | bandar
# Processing Record 145 of Set 3 | porto nacional
# Processing Record 146 of Set 3 | arecibo
# Processing Record 147 of Set 3 | iqaluit
# Processing Record 148 of Set 3 | hualmay
# Processing Record 149 of Set 3 | mar del plata
# Processing Record 150 of Set 3 | isangel
# Processing Record 151 of Set 4 | kruisfontein
# Processing Record 152 of Set 4 | codrington
# Processing Record 153 of Set 4 | pacifica
# Processing Record 154 of Set 4 | salvador
# Processing Record 155 of Set 4 | buraydah
# Processing Record 156 of Set 4 | qaanaaq
# Processing Record 157 of Set 4 | taos
# Processing Record 158 of Set 4 | maragogi
# Processing Record 159 of Set 4 | wa
# City not found. Skipping...
# Processing Record 160 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 161 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 162 of Set 4 | innisfail
# Processing Record 163 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 164 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 165 of Set 4 | gorontalo
# Processing Record 166 of Set 4 | te anau
# Processing Record 167 of Set 4 | kulhudhuffushi
# Processing Record 168 of Set 4 | ribeira grande
# Processing Record 169 of Set 4 | vila velha
# Processing Record 170 of Set 4 | carnarvon
# Processing Record 171 of Set 4 | swan hill
# Processing Record 172 of Set 4 | los llanos de aridane
# Processing Record 173 of Set 4 | porto novo
# Processing Record 174 of Set 4 | norman wells
# Processing Record 175 of Set 4 | qaqortoq
# Processing Record 176 of Set 4 | castro
# Processing Record 177 of Set 4 | krishnanagar
# Processing Record 178 of Set 4 | kargil
# Processing Record 179 of Set 4 | changzhou
# Processing Record 180 of Set 4 | general roca
# Processing Record 181 of Set 4 | kismayo
# Processing Record 182 of Set 4 | port lincoln
# Processing Record 183 of Set 4 | caxito
# Processing Record 184 of Set 4 | vega baja
# Processing Record 185 of Set 4 | tigre
# Processing Record 186 of Set 4 | omboue
# Processing Record 187 of Set 4 | hobyo
# Processing Record 188 of Set 4 | katsuura
# Processing Record 189 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 190 of Set 4 | porto santo
# Processing Record 191 of Set 4 | soyo
# Processing Record 192 of Set 4 | kenai
# Processing Record 193 of Set 4 | ormara
# Processing Record 194 of Set 4 | khani
# Processing Record 195 of Set 4 | azangaro
# Processing Record 196 of Set 4 | maceio
# Processing Record 197 of Set 4 | phetchabun
# Processing Record 198 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 199 of Set 4 | jamestown
# Processing Record 200 of Set 4 | sereflikochisar
# Processing Record 201 of Set 5 | maracacume
# Processing Record 202 of Set 5 | bengkulu
# Processing Record 203 of Set 5 | zunyi
# Processing Record 204 of Set 5 | broken hill
# Processing Record 205 of Set 5 | henderson
# Processing Record 206 of Set 5 | saint-augustin
# Processing Record 207 of Set 5 | minuri
# Processing Record 208 of Set 5 | ghoti
# Processing Record 209 of Set 5 | reitz
# Processing Record 210 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 211 of Set 5 | seversk
# Processing Record 212 of Set 5 | alofi
# Processing Record 213 of Set 5 | naliya
# Processing Record 214 of Set 5 | acarau
# Processing Record 215 of Set 5 | flinders
# Processing Record 216 of Set 5 | galesti
# Processing Record 217 of Set 5 | papara
# Processing Record 218 of Set 5 | cherskiy
# Processing Record 219 of Set 5 | upington
# Processing Record 220 of Set 5 | okandja
# City not found. Skipping...
# Processing Record 221 of Set 5 | umea
# Processing Record 222 of Set 5 | dunyapur
# Processing Record 223 of Set 5 | mecca
# Processing Record 224 of Set 5 | alice springs
# Processing Record 225 of Set 5 | samarai
# Processing Record 226 of Set 5 | ahipara
# Processing Record 227 of Set 5 | erenhot
# Processing Record 228 of Set 5 | llanes
# Processing Record 229 of Set 5 | hongjiang
# Processing Record 230 of Set 5 | peniche
# Processing Record 231 of Set 5 | plouzane
# Processing Record 232 of Set 5 | jardim
# Processing Record 233 of Set 5 | quatre cocos
# Processing Record 234 of Set 5 | lethem
# Processing Record 235 of Set 5 | porangatu
# Processing Record 236 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 237 of Set 5 | puerto colombia
# Processing Record 238 of Set 5 | kyren
# Processing Record 239 of Set 5 | puerto leguizamo
# Processing Record 240 of Set 5 | geraldton
# Processing Record 241 of Set 5 | kavaratti
# Processing Record 242 of Set 5 | saryg-sep
# Processing Record 243 of Set 5 | aquiraz
# Processing Record 244 of Set 5 | ambulu
# Processing Record 245 of Set 5 | haines junction
# Processing Record 246 of Set 5 | bafoulabe
# Processing Record 247 of Set 5 | azrow
# City not found. Skipping...
# Processing Record 248 of Set 5 | talnakh
# Processing Record 249 of Set 5 | shangqiu
# Processing Record 250 of Set 5 | adrar
# Processing Record 251 of Set 6 | sobolevo
# Processing Record 252 of Set 6 | klaksvik
# Processing Record 253 of Set 6 | rakhya
# City not found. Skipping...
# Processing Record 254 of Set 6 | pochutla
# Processing Record 255 of Set 6 | abapo
# Processing Record 256 of Set 6 | maneromango
# Processing Record 257 of Set 6 | ilulissat
# Processing Record 258 of Set 6 | gasa
# Processing Record 259 of Set 6 | cambridge
# Processing Record 260 of Set 6 | ayan
# Processing Record 261 of Set 6 | vestmannaeyjar
# Processing Record 262 of Set 6 | sao luiz gonzaga
# Processing Record 263 of Set 6 | parabel
# Processing Record 264 of Set 6 | vandra
# Processing Record 265 of Set 6 | zonhoven
# Processing Record 266 of Set 6 | maua
# Processing Record 267 of Set 6 | belaya gora
# Processing Record 268 of Set 6 | shahrud
# Processing Record 269 of Set 6 | kuala kangsar
# Processing Record 270 of Set 6 | honolulu
# Processing Record 271 of Set 6 | oranjemund
# Processing Record 272 of Set 6 | andros town
# Processing Record 273 of Set 6 | vanimo
# Processing Record 274 of Set 6 | isabela
# Processing Record 275 of Set 6 | kandla
# Processing Record 276 of Set 6 | xiongshi
# City not found. Skipping...
# Processing Record 277 of Set 6 | lewiston
# Processing Record 278 of Set 6 | gairo
# Processing Record 279 of Set 6 | srivardhan
# Processing Record 280 of Set 6 | visby
# Processing Record 281 of Set 6 | formosa do rio preto
# Processing Record 282 of Set 6 | sitka
# Processing Record 283 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 284 of Set 6 | bethel
# Processing Record 285 of Set 6 | kabinda
# Processing Record 286 of Set 6 | san juan
# Processing Record 287 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 288 of Set 6 | terenos
# Processing Record 289 of Set 6 | udalguri
# Processing Record 290 of Set 6 | berezovyy
# Processing Record 291 of Set 6 | ojinaga
# Processing Record 292 of Set 6 | khatanga
# Processing Record 293 of Set 6 | college
# Processing Record 294 of Set 6 | nanortalik
# Processing Record 295 of Set 6 | kingston
# Processing Record 296 of Set 6 | vilyuysk
# Processing Record 297 of Set 6 | borogontsy
# Processing Record 298 of Set 6 | sisophon
# Processing Record 299 of Set 6 | rabo de peixe
# Processing Record 300 of Set 6 | san andres
# Processing Record 301 of Set 7 | prainha
# Processing Record 302 of Set 7 | morant bay
# Processing Record 303 of Set 7 | lompoc
# Processing Record 304 of Set 7 | palauig
# Processing Record 305 of Set 7 | port moresby
# Processing Record 306 of Set 7 | necochea
# Processing Record 307 of Set 7 | novyy urengoy
# Processing Record 308 of Set 7 | otane
# Processing Record 309 of Set 7 | gamba
# Processing Record 310 of Set 7 | fier
# Processing Record 311 of Set 7 | nizhniy kuranakh
# Processing Record 312 of Set 7 | pervomaysk
# Processing Record 313 of Set 7 | skibbereen
# Processing Record 314 of Set 7 | pierre
# Processing Record 315 of Set 7 | vvedenskoye
# Processing Record 316 of Set 7 | porto walter
# Processing Record 317 of Set 7 | buy
# Processing Record 318 of Set 7 | selinia
# Processing Record 319 of Set 7 | aksaray
# Processing Record 320 of Set 7 | labrea
# Processing Record 321 of Set 7 | solnechnyy
# Processing Record 322 of Set 7 | el sauzal
# Processing Record 323 of Set 7 | itacoatiara
# Processing Record 324 of Set 7 | harper
# Processing Record 325 of Set 7 | ust-charyshskaya pristan
# Processing Record 326 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 327 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 328 of Set 7 | dimitrovgrad
# Processing Record 329 of Set 7 | grabovo
# Processing Record 330 of Set 7 | korla
# Processing Record 331 of Set 7 | hofn
# Processing Record 332 of Set 7 | neepawa
# Processing Record 333 of Set 7 | burla
# Processing Record 334 of Set 7 | grindavik
# Processing Record 335 of Set 7 | nishihara
# Processing Record 336 of Set 7 | kahului
# Processing Record 337 of Set 7 | hakvik
# City not found. Skipping...
# Processing Record 338 of Set 7 | jalu
# Processing Record 339 of Set 7 | ngunguru
# Processing Record 340 of Set 7 | oranjestad
# Processing Record 341 of Set 7 | pathein
# Processing Record 342 of Set 7 | saint-louis
# Processing Record 343 of Set 7 | henties bay
# Processing Record 344 of Set 7 | taoudenni
# Processing Record 345 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 346 of Set 7 | richards bay
# Processing Record 347 of Set 7 | black river
# Processing Record 348 of Set 7 | worthington
# Processing Record 349 of Set 7 | kalanchak
# Processing Record 350 of Set 7 | axim
# Processing Record 351 of Set 8 | bara
# Processing Record 352 of Set 8 | atambua
# Processing Record 353 of Set 8 | dingle
# Processing Record 354 of Set 8 | hunchun
# Processing Record 355 of Set 8 | mattru
# Processing Record 356 of Set 8 | palora
# Processing Record 357 of Set 8 | sovetskiy
# Processing Record 358 of Set 8 | ambilobe
# Processing Record 359 of Set 8 | rawson
# Processing Record 360 of Set 8 | shingu
# Processing Record 361 of Set 8 | portland
# Processing Record 362 of Set 8 | nome
# Processing Record 363 of Set 8 | bakau
# Processing Record 364 of Set 8 | lavrentiya
# Processing Record 365 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 366 of Set 8 | guadalajara
# Processing Record 367 of Set 8 | oistins
# Processing Record 368 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 369 of Set 8 | kem
# Processing Record 370 of Set 8 | reporoa
# Processing Record 371 of Set 8 | vao
# Processing Record 372 of Set 8 | aklavik
# Processing Record 373 of Set 8 | ampanihy
# Processing Record 374 of Set 8 | san cristobal
# Processing Record 375 of Set 8 | moree
# Processing Record 376 of Set 8 | pineville
# Processing Record 377 of Set 8 | gold coast
# Processing Record 378 of Set 8 | clyde river
# Processing Record 379 of Set 8 | cap-aux-meules
# Processing Record 380 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 381 of Set 8 | doume
# Processing Record 382 of Set 8 | saskylakh
# Processing Record 383 of Set 8 | lalmohan
# Processing Record 384 of Set 8 | faanui
# Processing Record 385 of Set 8 | astana
# Processing Record 386 of Set 8 | peleduy
# Processing Record 387 of Set 8 | muros
# Processing Record 388 of Set 8 | cuamba
# Processing Record 389 of Set 8 | high level
# Processing Record 390 of Set 8 | coquimbo
# Processing Record 391 of Set 8 | labuan
# Processing Record 392 of Set 8 | villaviciosa
# Processing Record 393 of Set 8 | kaeo
# Processing Record 394 of Set 8 | khandyga
# Processing Record 395 of Set 8 | ust-kuyga
# Processing Record 396 of Set 8 | sulangan
# Processing Record 397 of Set 8 | san marcos
# Processing Record 398 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 399 of Set 8 | kuytun
# Processing Record 400 of Set 8 | wanning
# Processing Record 401 of Set 9 | bossangoa
# Processing Record 402 of Set 9 | antofagasta
# Processing Record 403 of Set 9 | diapaga
# Processing Record 404 of Set 9 | carlisle
# Processing Record 405 of Set 9 | zhangye
# Processing Record 406 of Set 9 | wana
# Processing Record 407 of Set 9 | traverse city
# Processing Record 408 of Set 9 | padang
# Processing Record 409 of Set 9 | qeshm
# Processing Record 410 of Set 9 | kidodi
# Processing Record 411 of Set 9 | ayorou
# Processing Record 412 of Set 9 | lockhart
# Processing Record 413 of Set 9 | areosa
# Processing Record 414 of Set 9 | wanaka
# Processing Record 415 of Set 9 | salalah
# Processing Record 416 of Set 9 | goundam
# Processing Record 417 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 418 of Set 9 | hamilton
# Processing Record 419 of Set 9 | fortuna
# Processing Record 420 of Set 9 | kouroussa
# Processing Record 421 of Set 9 | rio pardo de minas
# Processing Record 422 of Set 9 | marzuq
# Processing Record 423 of Set 9 | timizart
# Processing Record 424 of Set 9 | port hedland
# Processing Record 425 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 426 of Set 9 | jatai
# Processing Record 427 of Set 9 | houma
# Processing Record 428 of Set 9 | sulecin
# Processing Record 429 of Set 9 | stellenbosch
# Processing Record 430 of Set 9 | lorengau
# Processing Record 431 of Set 9 | suraabad
# Processing Record 432 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 433 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 434 of Set 9 | aripuana
# Processing Record 435 of Set 9 | sinnamary
# Processing Record 436 of Set 9 | tomatlan
# Processing Record 437 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 438 of Set 9 | mandalgovi
# Processing Record 439 of Set 9 | margate
# Processing Record 440 of Set 9 | matara
# Processing Record 441 of Set 9 | sao gabriel da cachoeira
# Processing Record 442 of Set 9 | port hardy
# Processing Record 443 of Set 9 | saraland
# Processing Record 444 of Set 9 | mauganj
# Processing Record 445 of Set 9 | sur
# Processing Record 446 of Set 9 | loiza
# Processing Record 447 of Set 9 | nanyamba
# Processing Record 448 of Set 9 | doka
# Processing Record 449 of Set 9 | berlevag
# Processing Record 450 of Set 9 | pucallpa
# Processing Record 451 of Set 10 | narsaq
# Processing Record 452 of Set 10 | barranca
# Processing Record 453 of Set 10 | chicama
# Processing Record 454 of Set 10 | sao filipe
# Processing Record 455 of Set 10 | holme
# Processing Record 456 of Set 10 | bud
# Processing Record 457 of Set 10 | kununurra
# Processing Record 458 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 459 of Set 10 | leningradskiy
# Processing Record 460 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 461 of Set 10 | rio gallegos
# Processing Record 462 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 463 of Set 10 | calvinia
# Processing Record 464 of Set 10 | saint-denis
# Processing Record 465 of Set 10 | yenagoa
# Processing Record 466 of Set 10 | guipavas
# Processing Record 467 of Set 10 | sault sainte marie
# Processing Record 468 of Set 10 | puerto pinasco
# City not found. Skipping...
# Processing Record 469 of Set 10 | verkhnyaya inta
# Processing Record 470 of Set 10 | bima
# Processing Record 471 of Set 10 | hazorasp
# Processing Record 472 of Set 10 | cabo san lucas
# Processing Record 473 of Set 10 | macon
# Processing Record 474 of Set 10 | broome
# Processing Record 475 of Set 10 | shitkino
# Processing Record 476 of Set 10 | saurimo
# Processing Record 477 of Set 10 | montepuez
# Processing Record 478 of Set 10 | lagos
# Processing Record 479 of Set 10 | aksum
# Processing Record 480 of Set 10 | eureka
# Processing Record 481 of Set 10 | luba
# Processing Record 482 of Set 10 | batagay-alyta
# Processing Record 483 of Set 10 | fort nelson
# Processing Record 484 of Set 10 | kijang
# Processing Record 485 of Set 10 | beloha
# Processing Record 486 of Set 10 | yulara
# Processing Record 487 of Set 10 | sistranda
# Processing Record 488 of Set 10 | penzance
# Processing Record 489 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 490 of Set 10 | fukue
# Processing Record 491 of Set 10 | kasangulu
# Processing Record 492 of Set 10 | miyang
# Processing Record 493 of Set 10 | el jicaro
# Processing Record 494 of Set 10 | inirida
# Processing Record 495 of Set 10 | visnes
# Processing Record 496 of Set 10 | champerico
# Processing Record 497 of Set 10 | ouesso
# Processing Record 498 of Set 10 | merauke
# Processing Record 499 of Set 10 | kilindoni
# Processing Record 500 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 501 of Set 11 | zlitan
# Processing Record 502 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 503 of Set 11 | birjand
# Processing Record 504 of Set 11 | saint-pierre
# Processing Record 505 of Set 11 | kudahuvadhoo
# Processing Record 506 of Set 11 | torbay
# Processing Record 507 of Set 11 | florida
# Processing Record 508 of Set 11 | karla
# Processing Record 509 of Set 11 | contamana
# Processing Record 510 of Set 11 | rudnaya pristan
# Processing Record 511 of Set 11 | lexington
# Processing Record 512 of Set 11 | guapi
# Processing Record 513 of Set 11 | huejuquilla el alto
# Processing Record 514 of Set 11 | slavuta
# Processing Record 515 of Set 11 | buala
# Processing Record 516 of Set 11 | auki
# Processing Record 517 of Set 11 | svetlyy
# Processing Record 518 of Set 11 | yar-sale
# Processing Record 519 of Set 11 | kasongo-lunda
# Processing Record 520 of Set 11 | pasni
# Processing Record 521 of Set 11 | alghero
# Processing Record 522 of Set 11 | salisbury
# Processing Record 523 of Set 11 | novaya ladoga
# Processing Record 524 of Set 11 | sirjan
# Processing Record 525 of Set 11 | iquitos
# Processing Record 526 of Set 11 | puebloviejo
# Processing Record 527 of Set 11 | vila
# Processing Record 528 of Set 11 | aguas belas
# Processing Record 529 of Set 11 | ikalamavony
# Processing Record 530 of Set 11 | naberera
# Processing Record 531 of Set 11 | tigil
# Processing Record 532 of Set 11 | port macquarie
# Processing Record 533 of Set 11 | grimari
# City not found. Skipping...
# Processing Record 534 of Set 11 | dire dawa
# Processing Record 535 of Set 11 | rantauprapat
# Processing Record 536 of Set 11 | kalmunai
# Processing Record 537 of Set 11 | kungurtug
# Processing Record 538 of Set 11 | azul
# Processing Record 539 of Set 11 | laguna
# Processing Record 540 of Set 11 | minbu
# Processing Record 541 of Set 11 | lufilufi
# Processing Record 542 of Set 11 | chumikan
# Processing Record 543 of Set 11 | arlit
# Processing Record 544 of Set 11 | santa lucia
# Processing Record 545 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 546 of Set 11 | bowen
# Processing Record 547 of Set 11 | podlesnoye
# Processing Record 548 of Set 11 | cap malheureux
# Processing Record 549 of Set 11 | paita
# Processing Record 550 of Set 11 | ossora
# Processing Record 551 of Set 12 | moyale
# Processing Record 552 of Set 12 | nova granada
# Processing Record 553 of Set 12 | namtsy
# Processing Record 554 of Set 12 | oriximina
# Processing Record 555 of Set 12 | makakilo city
# Processing Record 556 of Set 12 | pimentel
# Processing Record 557 of Set 12 | cockburn town
# Processing Record 558 of Set 12 | garowe
# Processing Record 559 of Set 12 | birzai
# Processing Record 560 of Set 12 | guerrero negro
# Processing Record 561 of Set 12 | nioaque
# Processing Record 562 of Set 12 | plettenberg bay
# Processing Record 563 of Set 12 | muli
# Processing Record 564 of Set 12 | sarakhs
# Processing Record 565 of Set 12 | sivas
# Processing Record 566 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 567 of Set 12 | koumac
# Processing Record 568 of Set 12 | teguldet
# Processing Record 569 of Set 12 | gavle
# Processing Record 570 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 571 of Set 12 | visavadar
# Processing Record 572 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 573 of Set 12 | umba
# Processing Record 574 of Set 12 | salmas
# Processing Record 575 of Set 12 | aksarka
# Processing Record 576 of Set 12 | xai-xai
# Processing Record 577 of Set 12 | kumluca
# Processing Record 578 of Set 12 | esperance
# Processing Record 579 of Set 12 | wadsworth
# Processing Record 580 of Set 12 | mezen
# Processing Record 581 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 582 of Set 12 | gazanjyk
# Processing Record 583 of Set 12 | nara
# Processing Record 584 of Set 12 | iquique
# Processing Record 585 of Set 12 | colares
# Processing Record 586 of Set 12 | bacolod
# Processing Record 587 of Set 12 | svarstad
# Processing Record 588 of Set 12 | dandong
# Processing Record 589 of Set 12 | manali
# Processing Record 590 of Set 12 | vardo
# Processing Record 591 of Set 12 | burica
# City not found. Skipping...
# Processing Record 592 of Set 12 | zhigansk
# Processing Record 593 of Set 12 | sisimiut
# Processing Record 594 of Set 12 | kargasok
# Processing Record 595 of Set 12 | mayor pablo lagerenza
# Processing Record 596 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 597 of Set 12 | victor harbor
# Processing Record 598 of Set 12 | talas
# Processing Record 599 of Set 12 | opuwo
# Processing Record 600 of Set 12 | conde
# Processing Record 601 of Set 13 | longyan
# Processing Record 602 of Set 13 | gat
# Processing Record 603 of Set 13 | tchollire
# Processing Record 604 of Set 13 | zimovniki
# Processing Record 605 of Set 13 | hokitika
# Processing Record 606 of Set 13 | marsa matruh
# Processing Record 607 of Set 13 | tilichiki
# Processing Record 608 of Set 13 | forbes
# Processing Record 609 of Set 13 | evensk
# Processing Record 610 of Set 13 | kailua
# Processing Record 611 of Set 13 | blama
# Processing Record 612 of Set 13 | lubao
# Processing Record 613 of Set 13 | adelaide
# Processing Record 614 of Set 13 | slave lake
# Processing Record 615 of Set 13 | turbat
# Processing Record 616 of Set 13 | develi
# Processing Record 617 of Set 13 | lasa
# Processing Record 618 of Set 13 | moerai
# Processing Record 619 of Set 13 | natal
# Processing Record 620 of Set 13 | san ramon
# Processing Record 621 of Set 13 | naze
# Processing Record 622 of Set 13 | serowe
# Processing Record 623 of Set 13 | marawi
# Processing Record 624 of Set 13 | saint-georges
# Processing Record 625 of Set 13 | hede
# Processing Record 626 of Set 13 | bull savanna
# Processing Record 627 of Set 13 | merrill
# Processing Record 628 of Set 13 | baglung
# Processing Record 629 of Set 13 | hwange
# Processing Record 630 of Set 13 | kirakira
# Processing Record 631 of Set 13 | calama
# Processing Record 632 of Set 13 | anamur
# Processing Record 633 of Set 13 | chekalin
# Processing Record 634 of Set 13 | qurayyat
# Processing Record 635 of Set 13 | kamenka
# Processing Record 636 of Set 13 | coihaique
# Processing Record 637 of Set 13 | husavik
# Processing Record 638 of Set 13 | benjamin constant
# Processing Record 639 of Set 13 | fagernes
# Processing Record 640 of Set 13 | teya
# Processing Record 641 of Set 13 | upata
# Processing Record 642 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 643 of Set 13 | cayenne
# Processing Record 644 of Set 13 | teknaf
# Processing Record 645 of Set 13 | ures
# Processing Record 646 of Set 13 | buin
# Processing Record 647 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 648 of Set 13 | bemidji
# Processing Record 649 of Set 13 | bisho
# Processing Record 650 of Set 13 | barvinkove
# Processing Record 651 of Set 14 | bosaso
# Processing Record 652 of Set 14 | hounde
# Processing Record 653 of Set 14 | truro
# Processing Record 654 of Set 14 | zhanaozen
# Processing Record 655 of Set 14 | tautira
# Processing Record 656 of Set 14 | energetik
# Processing Record 657 of Set 14 | thinadhoo
# Processing Record 658 of Set 14 | ghanzi
# Processing Record 659 of Set 14 | buckingham
# Processing Record 660 of Set 14 | havoysund
# Processing Record 661 of Set 14 | nantucket
# Processing Record 662 of Set 14 | la ronge
# Processing Record 663 of Set 14 | bontang
# Processing Record 664 of Set 14 | lakatoro
# Processing Record 665 of Set 14 | puerto carreno
# Processing Record 666 of Set 14 | ca mau
# Processing Record 667 of Set 14 | saltabarranca
# Processing Record 668 of Set 14 | tolaga bay
# Processing Record 669 of Set 14 | olinda
# Processing Record 670 of Set 14 | hervey bay
# Processing Record 671 of Set 14 | seda
# Processing Record 672 of Set 14 | noumea
# Processing Record 673 of Set 14 | sorong
# Processing Record 674 of Set 14 | mbale
# Processing Record 675 of Set 14 | waipawa
# Processing Record 676 of Set 14 | tabas
# Processing Record 677 of Set 14 | kuusamo
# Processing Record 678 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 679 of Set 14 | skjervoy
# Processing Record 680 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 681 of Set 14 | sola
# Processing Record 682 of Set 14 | bambanglipuro
# Processing Record 683 of Set 14 | biak
# Processing Record 684 of Set 14 | russell
# Processing Record 685 of Set 14 | beyneu
# Processing Record 686 of Set 14 | shipitsyno
# Processing Record 687 of Set 14 | ennis
# Processing Record 688 of Set 14 | poum
# Processing Record 689 of Set 14 | conakry
# Processing Record 690 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 691 of Set 14 | oksfjord
# Processing Record 692 of Set 14 | custodia
# Processing Record 693 of Set 14 | acapulco
# Processing Record 694 of Set 14 | aljezur
# Processing Record 695 of Set 14 | kutum
# Processing Record 696 of Set 14 | bend
# Processing Record 697 of Set 14 | talah
# City not found. Skipping...
# Processing Record 698 of Set 14 | paranaiba
# Processing Record 699 of Set 14 | ust-omchug
# Processing Record 700 of Set 14 | damnoen saduak
# Processing Record 701 of Set 15 | tikrit
# Processing Record 702 of Set 15 | dingzhou
# Processing Record 703 of Set 15 | villa carlos paz
# Processing Record 704 of Set 15 | riyadh
# Processing Record 705 of Set 15 | congonhas
# Processing Record 706 of Set 15 | xingyi
# Processing Record 707 of Set 15 | mount isa
# Processing Record 708 of Set 15 | gladstone
# Processing Record 709 of Set 15 | sibolga
# Processing Record 710 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 711 of Set 15 | arteaga
# Processing Record 712 of Set 15 | smyrna
# Processing Record 713 of Set 15 | juchipila
# Processing Record 714 of Set 15 | narasannapeta
# Processing Record 715 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 716 of Set 15 | gizo
# Processing Record 717 of Set 15 | morehead
# Processing Record 718 of Set 15 | mogosoaia
# Processing Record 719 of Set 15 | bad lauterberg
# Processing Record 720 of Set 15 | sioux lookout
# Processing Record 721 of Set 15 | inongo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Yellowknife  62.4560 -114.3525     22.41        62          75
# 1        Westport  41.1415  -73.3579     45.95        92         100
# 2         Mataura -46.1927  168.8643     50.04        89          93
# 3         Shimoda  34.6667  138.9500     49.10        91         100
# 4  Saint-Philippe -21.3585   55.7679     74.79        92         100
# 5           Pisco -13.7000  -76.2167     73.45        64           0
# 6           Gejiu  23.3060  103.1635     39.63        75           1
# 7    Saint George  37.1041 -113.5841     76.42        20           0
# 8         Ushuaia -54.8000  -68.3000     38.86        87          40
# 9         Kavieng  -2.5744  150.7967     81.61        75         100
#
#    Wind Speed Country   Current Description
# 0       17.27      CA         broken clouds
# 1        4.61      US       overcast clouds
# 2        1.86      NZ       overcast clouds
# 3       17.87      JP         moderate rain
# 4       11.10      RE  heavy intensity rain
# 5       20.71      PE             clear sky
# 6        2.84      CN             clear sky
# 7        5.75      US             clear sky
# 8       20.71      AR      scattered clouds
# 9        5.23      PG            light rain

# %%
#Reorder Columns
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Yellowknife      CA  62.4560 -114.3525     22.41        62          75
# 1        Westport      US  41.1415  -73.3579     45.95        92         100
# 2         Mataura      NZ -46.1927  168.8643     50.04        89          93
# 3         Shimoda      JP  34.6667  138.9500     49.10        91         100
# 4  Saint-Philippe      RE -21.3585   55.7679     74.79        92         100
# 5           Pisco      PE -13.7000  -76.2167     73.45        64           0
# 6           Gejiu      CN  23.3060  103.1635     39.63        75           1
# 7    Saint George      US  37.1041 -113.5841     76.42        20           0
# 8         Ushuaia      AR -54.8000  -68.3000     38.86        87          40
# 9         Kavieng      PG  -2.5744  150.7967     81.61        75         100
#
#    Wind Speed   Current Description
# 0       17.27         broken clouds
# 1        4.61       overcast clouds
# 2        1.86       overcast clouds
# 3       17.87         moderate rain
# 4       11.10  heavy intensity rain
# 5       20.71             clear sky
# 6        2.84             clear sky
# 7        5.75             clear sky
# 8       20.71      scattered clouds
# 9        5.23            light rain

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/dantw/Desktop/Vanessa/Module 6/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"


# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
